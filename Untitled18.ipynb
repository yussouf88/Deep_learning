# %% [markdown]
# <a href="https://colab.research.google.com/github/yussouf88/Deep_learning/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ul = files.upload()
df = pd.read_csv(io.BytesIO(ul['f2.csv']))
# Out:
#      <input type="file" id="files-01aa8ecb-d898-494c-87bb-66b84a11f856" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01aa8ecb-d898-494c-87bb-66b84a11f856">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = df.query('mem_col.isin([8,9,10])')

# %%
df2 =df[(df.mem_sn<=500) & (df.mem_py.isin([1987,1988])) & df.mem_col.isin([8,9,10])]

# %%
df3 = pd.concat([df1,df2])

# %%
df2
# Out:
# Empty DataFrame
# Columns: [mem_sn, mem_nm, mem_py, mem_col]
# Index: []

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df3
# Out:
#     mem_sn                      mem_nm  mem_py  mem_col
# 6       74    Maksud-Ul-Alam Choudhury    1987        6
# 7       76  Mohd Golam Rabbani Shaheen    1988        7
# 8       77       Mohammad Amanul Hoque    1988        7
# 9      124                Sharif Ahmed    1988        7
# 21     272           Md Shafiqul Islam    1988        5
# 67     469             Md Saidul Islam    1987        7
# 71     488            Mushfiqur Rahman    1988        5
